# %%
# !mkdir pretrained
# %cd pretrained
# !echo "##### downloading pretrained weight file and config pbtxt file"
# !wget  http://download.tensorflow.org/models/object_detection/ssd_mobilenet_v2_coco_2018_03_29.tar.gz
# !wget https://raw.githubusercontent.com/opencv/opencv_extra/master/testdata/dnn/ssd_mobilenet_v2_coco_2018_03_29.pbtxt


# tar 파일 압축 해제
# !echo "##### uncompressing tar file"
# !tar -xvf ssd_mobilenet_v2_coco_2018_03_29.tar.gz

# tar 파일 삭제
# !echo "##### deleting tar file" 
# !rm *.gz

# weight파일과 config 파일이 있는 pretrained/faster_rcnn_resnet50_coco_2018_01_28 디렉토리 내부 확인 
# !echo "##### check out pretrained/ssd_mobilenet_v2_coco_2018_03_29"
# !ls /content/pretrained/ssd_mobilenet_v2_coco_2018_03_29
# Out:
# /content/pretrained
# ##### downloading pretrained weight file and config pbtxt file
# --2021-01-02 08:42:10--  http://download.tensorflow.org/models/object_detection/ssd_mobilenet_v2_coco_2018_03_29.tar.gz
# Resolving download.tensorflow.org (download.tensorflow.org)... 108.177.127.128, 2a00:1450:4013:c07::80
# Connecting to download.tensorflow.org (download.tensorflow.org)|108.177.127.128|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 187925923 (179M) [application/x-tar]
# Saving to: ‘ssd_mobilenet_v2_coco_2018_03_29.tar.gz’
#
# ssd_mobilenet_v2_co 100%[===================>] 179.22M   105MB/s    in 1.7s
#
# 2021-01-02 08:42:12 (105 MB/s) - ‘ssd_mobilenet_v2_coco_2018_03_29.tar.gz’ saved [187925923/187925923]
#
# --2021-01-02 08:42:12--  https://raw.githubusercontent.com/opencv/opencv_extra/master/testdata/dnn/ssd_mobilenet_v2_coco_2018_03_29.pbtxt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 115601 (113K) [text/plain]
# Saving to: ‘ssd_mobilenet_v2_coco_2018_03_29.pbtxt’
#
# ssd_mobilenet_v2_co 100%[===================>] 112.89K  --.-KB/s    in 0.009s
#
# 2021-01-02 08:42:12 (12.6 MB/s) - ‘ssd_mobilenet_v2_coco_2018_03_29.pbtxt’ saved [115601/115601]
#
# ##### uncompressing tar file
# ssd_mobilenet_v2_coco_2018_03_29/checkpoint
# ssd_mobilenet_v2_coco_2018_03_29/model.ckpt.meta
# ssd_mobilenet_v2_coco_2018_03_29/pipeline.config
# ssd_mobilenet_v2_coco_2018_03_29/saved_model/saved_model.pb
# ssd_mobilenet_v2_coco_2018_03_29/frozen_inference_graph.pb
# ssd_mobilenet_v2_coco_2018_03_29/saved_model/
# ssd_mobilenet_v2_coco_2018_03_29/saved_model/variables/
# ssd_mobilenet_v2_coco_2018_03_29/model.ckpt.index
# ssd_mobilenet_v2_coco_2018_03_29/
# ssd_mobilenet_v2_coco_2018_03_29/model.ckpt.data-00000-of-00001
# ##### deleting tar file
# ##### check out pretrained/ssd_mobilenet_v2_coco_2018_03_29
# checkpoint			model.ckpt.index  saved_model
# frozen_inference_graph.pb	model.ckpt.meta
# model.ckpt.data-00000-of-00001	pipeline.config

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp -r /content/drive/MyDrive/data /content

# %%
# !pip install tensorflow==1.15
# !pip install keras==2.3
# Out:
# Collecting tensorflow==1.15
#   Downloading https://files.pythonhosted.org/packages/3f/98/5a99af92fb911d7a88a0005ad55005f35b4c1ba8d75fba02df726cd936e6/tensorflow-1.15.0-cp36-cp36m-manylinux2010_x86_64.whl (412.3MB)
#      |████████████████████████████████| 412.3MB 46kB/s
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (0.36.2)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (1.19.4)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (0.8.1)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (0.2.0)
# Collecting gast==0.2.2
#   Downloading https://files.pythonhosted.org/packages/4e/35/11749bf99b2d4e3cceb4d55ca22590b0d7c2c62b9de38ac4a4a7f4687421/gast-0.2.2.tar.gz
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (1.1.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (3.3.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (1.15.0)
# Collecting tensorboard<1.16.0,>=1.15.0
#   Downloading https://files.pythonhosted.org/packages/1e/e9/d3d747a97f7188f48aa5eda486907f3b345cd409f0a0850468ba867db246/tensorboard-1.15.0-py3-none-any.whl (3.8MB)
#      |████████████████████████████████| 3.8MB 48.5MB/s
# Collecting tensorflow-estimator==1.15.1
#   Downloading https://files.pythonhosted.org/packages/de/62/2ee9cd74c9fa2fa450877847ba560b260f5d0fb70ee0595203082dafcc9d/tensorflow_estimator-1.15.1-py2.py3-none-any.whl (503kB)
#      |████████████████████████████████| 512kB 53.8MB/s
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (1.12.1)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (1.32.0)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (3.12.4)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (0.10.0)
# Requirement already satisfied: keras-applications>=1.0.8 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (1.0.8)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15) (1.1.0)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow==1.15) (51.0.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow==1.15) (1.0.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow==1.15) (3.3.3)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.8->tensorflow==1.15) (2.10.0)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow==1.15) (3.3.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow==1.15) (3.4.0)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow==1.15) (3.7.4.3)
# Building wheels for collected packages: gast
#   Building wheel for gast (setup.py) ... done
#   Created wheel for gast: filename=gast-0.2.2-cp36-none-any.whl size=7540 sha256=39171d69f3897ebd6b82ad0c00f4af9b71b871b3ae5734ffd600ee92eca61f1d
#   Stored in directory: /root/.cache/pip/wheels/5c/2e/7e/a1d4d4fcebe6c381f378ce7743a3ced3699feb89bcfbdadadd
# Successfully built gast
# ERROR: tensorflow-probability 0.11.0 has requirement gast>=0.3.2, but you'll have gast 0.2.2 which is incompatible.
# Installing collected packages: gast, tensorboard, tensorflow-estimator, tensorflow
#   Found existing installation: gast 0.3.3
#     Uninstalling gast-0.3.3:
#       Successfully uninstalled gast-0.3.3
#   Found existing installation: tensorboard 2.4.0
#     Uninstalling tensorboard-2.4.0:
#       Successfully uninstalled tensorboard-2.4.0
#   Found existing installation: tensorflow-estimator 2.4.0
#     Uninstalling tensorflow-estimator-2.4.0:
#       Successfully uninstalled tensorflow-estimator-2.4.0
#   Found existing installation: tensorflow 2.4.0
#     Uninstalling tensorflow-2.4.0:
#       Successfully uninstalled tensorflow-2.4.0
# Successfully installed gast-0.2.2 tensorboard-1.15.0 tensorflow-1.15.0 tensorflow-estimator-1.15.1
# Requirement already satisfied: keras==2.3 in /usr/local/lib/python3.6/dist-packages (2.3.0)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from keras==2.3) (1.0.8)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras==2.3) (2.10.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from keras==2.3) (1.15.0)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from keras==2.3) (1.4.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from keras==2.3) (3.13)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from keras==2.3) (1.1.2)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from keras==2.3) (1.19.4)

# %%
import tensorflow as tf
import keras 

labels_to_names = {1:'person',2:'bicycle',3:'car',4:'motorcycle',5:'airplane',6:'bus',7:'train',8:'truck',9:'boat',10:'traffic light',
                    11:'fire hydrant',12:'street sign',13:'stop sign',14:'parking meter',15:'bench',16:'bird',17:'cat',18:'dog',19:'horse',20:'sheep',
                    21:'cow',22:'elephant',23:'bear',24:'zebra',25:'giraffe',26:'hat',27:'backpack',28:'umbrella',29:'shoe',30:'eye glasses',
                    31:'handbag',32:'tie',33:'suitcase',34:'frisbee',35:'skis',36:'snowboard',37:'sports ball',38:'kite',39:'baseball bat',40:'baseball glove',
                    41:'skateboard',42:'surfboard',43:'tennis racket',44:'bottle',45:'plate',46:'wine glass',47:'cup',48:'fork',49:'knife',50:'spoon',
                    51:'bowl',52:'banana',53:'apple',54:'sandwich',55:'orange',56:'broccoli',57:'carrot',58:'hot dog',59:'pizza',60:'donut',
                    61:'cake',62:'chair',63:'couch',64:'potted plant',65:'bed',66:'mirror',67:'dining table',68:'window',69:'desk',70:'toilet',
                    71:'door',72:'tv',73:'laptop',74:'mouse',75:'remote',76:'keyboard',77:'cell phone',78:'microwave',79:'oven',80:'toaster',
                    81:'sink',82:'refrigerator',83:'blender',84:'book',85:'clock',86:'vase',87:'scissors',88:'teddy bear',89:'hair drier',90:'toothbrush',
                    91:'hair brush'}

def get_tensor_detected_image(sess, img_array, use_copied_array):
    
    rows = img_array.shape[0]
    cols = img_array.shape[1]
    if use_copied_array:
        draw_img = img_array.copy()
    else:
        draw_img = img_array
    
    inp = cv2.resize(img_array, (300, 300))
    inp = inp[:, :, [2, 1, 0]]  # BGR2RGB
    

    start = time.time()
    # Object Detection 수행. 
    out = sess.run([sess.graph.get_tensor_by_name('num_detections:0'),
                    sess.graph.get_tensor_by_name('detection_scores:0'),
                    sess.graph.get_tensor_by_name('detection_boxes:0'),
                    sess.graph.get_tensor_by_name('detection_classes:0')],
                   feed_dict={'image_tensor:0': inp.reshape(1, inp.shape[0], inp.shape[1], 3)})
    
    green_color=(0, 255, 0)
    red_color=(0, 0, 255)
    
    # Bounding Box 시각화 
    # Detect된 Object 별로 bounding box 시각화 
    num_detections = int(out[0][0])
    for i in range(num_detections):
        # class id와 object class score, bounding box정보를 추출
        classId = int(out[3][0][i])
        score = float(out[1][0][i])
        bbox = [float(v) for v in out[2][0][i]]
        if score > 0.3:
            left = bbox[1] * cols
            top = bbox[0] * rows
            right = bbox[3] * cols
            bottom = bbox[2] * rows
            # cv2의 rectangle(), putText()로 bounding box의 클래스명 시각화 
            cv2.rectangle(draw_img, (int(left), int(top)), (int(right), int(bottom)), green_color, thickness=2)
            caption = "{}: {:.4f}".format(labels_to_names[classId], score)
            cv2.putText(draw_img, caption, (int(left), int(top - 5)), cv2.FONT_HERSHEY_SIMPLEX, 0.4, red_color, 1)
    
    print('Detection 수행시간:',round(time.time() - start, 3),"초")
    return draw_img
# Out:
# Using TensorFlow backend.

# %%
import numpy as np
import tensorflow as tf
import cv2
import time
import matplotlib.pyplot as plt
import os
# %matplotlib inline

default_dir = '/content'
default_ssd_dir = '/content/pretrained/ssd_mobilenet_v2_coco_2018_03_29'

video_input_path = os.path.join(default_dir, 'data/video/Night_Day_Chase.mp4')
# linux에서 video output의 확장자는 반드시 avi 로 설정 필요. 
video_output_path = os.path.join(default_dir, 'data/output/Night_Day_Chase_tensor_ssd_mobile_01.avi')

cap = cv2.VideoCapture(video_input_path)

codec = cv2.VideoWriter_fourcc(*'XVID')

vid_size = (round(cap.get(cv2.CAP_PROP_FRAME_WIDTH)),round(cap.get(cv2.CAP_PROP_FRAME_HEIGHT)))
vid_fps = cap.get(cv2.CAP_PROP_FPS)
    
vid_writer = cv2.VideoWriter(video_output_path, codec, vid_fps, vid_size) 

frame_cnt = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
print('총 Frame 갯수:', frame_cnt, 'FPS:', vid_fps )

green_color=(0, 255, 0)
red_color=(0, 0, 255)

# SSD+Mobilenet inference graph를 읽음. .
with tf.gfile.FastGFile(os.path.join(default_ssd_dir, 'frozen_inference_graph.pb'), 'rb') as f:
    graph_def = tf.GraphDef()
    graph_def.ParseFromString(f.read())
    
with tf.Session() as sess:
    # Session 시작하고 inference graph 모델 로딩 
    sess.graph.as_default()
    tf.import_graph_def(graph_def, name='')
    index = 0
    while True:
        hasFrame, img_frame = cap.read()
        if not hasFrame:
            print('더 이상 처리할 frame이 없습니다.')
            break

        draw_img_frame = get_tensor_detected_image(sess, img_frame, False)
        vid_writer.write(draw_img_frame)
    # end of while loop

vid_writer.release()
cap.release()
# Out:
# 총 Frame 갯수: 1383 FPS: 28.282227867912656
# Detection 수행시간: 2.797 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.13 초
# Detection 수행시간: 0.13 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.132 초
# Detection 수행시간: 0.135 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.13 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.125 초
# Detection 수행시간: 0.132 초
# Detection 수행시간: 0.131 초
# Detection 수행시간: 0.118 초
# Detection 수행시간: 0.125 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.112 초
# Detection 수행시간: 0.132 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.13 초
# Detection 수행시간: 0.133 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.132 초
# Detection 수행시간: 0.13 초
# Detection 수행시간: 0.103 초
# Detection 수행시간: 0.115 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.132 초
# Detection 수행시간: 0.137 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.134 초
# Detection 수행시간: 0.121 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.112 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.124 초
# Detection 수행시간: 0.092 초
# Detection 수행시간: 0.121 초
# Detection 수행시간: 0.134 초
# Detection 수행시간: 0.121 초
# Detection 수행시간: 0.135 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.13 초
# Detection 수행시간: 0.14 초
# Detection 수행시간: 0.14 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.135 초
# Detection 수행시간: 0.131 초
# Detection 수행시간: 0.114 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.132 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.132 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.13 초
# Detection 수행시간: 0.123 초
# Detection 수행시간: 0.133 초
# Detection 수행시간: 0.112 초
# Detection 수행시간: 0.119 초
# Detection 수행시간: 0.11 초
# Detection 수행시간: 0.138 초
# Detection 수행시간: 0.123 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.139 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.13 초
# Detection 수행시간: 0.118 초
# Detection 수행시간: 0.134 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.111 초
# Detection 수행시간: 0.092 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.133 초
# Detection 수행시간: 0.131 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.135 초
# Detection 수행시간: 0.123 초
# Detection 수행시간: 0.135 초
# Detection 수행시간: 0.124 초
# Detection 수행시간: 0.135 초
# Detection 수행시간: 0.134 초
# Detection 수행시간: 0.108 초
# Detection 수행시간: 0.089 초
# Detection 수행시간: 0.09 초
# Detection 수행시간: 0.122 초
# Detection 수행시간: 0.123 초
# Detection 수행시간: 0.124 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.136 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.132 초
# Detection 수행시간: 0.125 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.122 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.124 초
# Detection 수행시간: 0.136 초
# Detection 수행시간: 0.123 초
# Detection 수행시간: 0.134 초
# Detection 수행시간: 0.123 초
# Detection 수행시간: 0.13 초
# Detection 수행시간: 0.125 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.123 초
# Detection 수행시간: 0.109 초
# Detection 수행시간: 0.092 초
# Detection 수행시간: 0.145 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.124 초
# Detection 수행시간: 0.123 초
# Detection 수행시간: 0.138 초
# Detection 수행시간: 0.124 초
# Detection 수행시간: 0.132 초
# Detection 수행시간: 0.116 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.123 초
# Detection 수행시간: 0.131 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.095 초
# Detection 수행시간: 0.111 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.125 초
# Detection 수행시간: 0.133 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.138 초
# Detection 수행시간: 0.13 초
# Detection 수행시간: 0.133 초
# Detection 수행시간: 0.135 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.132 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.148 초
# Detection 수행시간: 0.133 초
# Detection 수행시간: 0.138 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.13 초
# Detection 수행시간: 0.13 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.134 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.13 초
# Detection 수행시간: 0.132 초
# Detection 수행시간: 0.104 초
# Detection 수행시간: 0.13 초
# Detection 수행시간: 0.133 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.118 초
# Detection 수행시간: 0.117 초
# Detection 수행시간: 0.132 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.132 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.121 초
# Detection 수행시간: 0.124 초
# Detection 수행시간: 0.124 초
# Detection 수행시간: 0.138 초
# Detection 수행시간: 0.119 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.125 초
# Detection 수행시간: 0.092 초
# Detection 수행시간: 0.122 초
# Detection 수행시간: 0.133 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.131 초
# Detection 수행시간: 0.13 초
# Detection 수행시간: 0.142 초
# Detection 수행시간: 0.132 초
# Detection 수행시간: 0.139 초
# Detection 수행시간: 0.124 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.131 초
# Detection 수행시간: 0.135 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.132 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.133 초
# Detection 수행시간: 0.136 초
# Detection 수행시간: 0.124 초
# Detection 수행시간: 0.134 초
# Detection 수행시간: 0.102 초
# Detection 수행시간: 0.097 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.13 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.13 초
# Detection 수행시간: 0.116 초
# Detection 수행시간: 0.133 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.131 초
# Detection 수행시간: 0.137 초
# Detection 수행시간: 0.131 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.135 초
# Detection 수행시간: 0.136 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.124 초
# Detection 수행시간: 0.114 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.136 초
# Detection 수행시간: 0.122 초
# Detection 수행시간: 0.114 초
# Detection 수행시간: 0.125 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.132 초
# Detection 수행시간: 0.135 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.131 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.131 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.132 초
# Detection 수행시간: 0.141 초
# Detection 수행시간: 0.132 초
# Detection 수행시간: 0.104 초
# Detection 수행시간: 0.138 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.125 초
# Detection 수행시간: 0.125 초
# Detection 수행시간: 0.138 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.134 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.125 초
# Detection 수행시간: 0.132 초
# Detection 수행시간: 0.131 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.12 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.124 초
# Detection 수행시간: 0.13 초
# Detection 수행시간: 0.144 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.13 초
# Detection 수행시간: 0.136 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.139 초
# Detection 수행시간: 0.123 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.131 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.125 초
# Detection 수행시간: 0.134 초
# Detection 수행시간: 0.134 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.133 초
# Detection 수행시간: 0.115 초
# Detection 수행시간: 0.123 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.125 초
# Detection 수행시간: 0.116 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.133 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.13 초
# Detection 수행시간: 0.124 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.137 초
# Detection 수행시간: 0.124 초
# Detection 수행시간: 0.131 초
# Detection 수행시간: 0.123 초
# Detection 수행시간: 0.117 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.131 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.133 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.118 초
# Detection 수행시간: 0.124 초
# Detection 수행시간: 0.131 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.125 초
# Detection 수행시간: 0.133 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.119 초
# Detection 수행시간: 0.132 초
# Detection 수행시간: 0.131 초
# Detection 수행시간: 0.131 초
# Detection 수행시간: 0.133 초
# Detection 수행시간: 0.13 초
# Detection 수행시간: 0.125 초
# Detection 수행시간: 0.102 초
# Detection 수행시간: 0.093 초
# Detection 수행시간: 0.121 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.13 초
# Detection 수행시간: 0.133 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.119 초
# Detection 수행시간: 0.133 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.124 초
# Detection 수행시간: 0.139 초
# Detection 수행시간: 0.124 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.115 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.124 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.139 초
# Detection 수행시간: 0.158 초
# Detection 수행시간: 0.123 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.124 초
# Detection 수행시간: 0.13 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.133 초
# Detection 수행시간: 0.12 초
# Detection 수행시간: 0.13 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.13 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.104 초
# Detection 수행시간: 0.15 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.132 초
# Detection 수행시간: 0.136 초
# Detection 수행시간: 0.131 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.135 초
# Detection 수행시간: 0.132 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.134 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.117 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.105 초
# Detection 수행시간: 0.124 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.134 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.136 초
# Detection 수행시간: 0.124 초
# Detection 수행시간: 0.124 초
# Detection 수행시간: 0.14 초
# Detection 수행시간: 0.131 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.124 초
# Detection 수행시간: 0.132 초
# Detection 수행시간: 0.131 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.132 초
# Detection 수행시간: 0.133 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.124 초
# Detection 수행시간: 0.135 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.13 초
# Detection 수행시간: 0.131 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.13 초
# Detection 수행시간: 0.098 초
# Detection 수행시간: 0.124 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.133 초
# Detection 수행시간: 0.13 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.124 초
# Detection 수행시간: 0.13 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.131 초
# Detection 수행시간: 0.122 초
# Detection 수행시간: 0.11 초
# Detection 수행시간: 0.134 초
# Detection 수행시간: 0.125 초
# Detection 수행시간: 0.134 초
# Detection 수행시간: 0.125 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.131 초
# Detection 수행시간: 0.125 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.138 초
# Detection 수행시간: 0.119 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.135 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.124 초
# Detection 수행시간: 0.13 초
# Detection 수행시간: 0.116 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.13 초
# Detection 수행시간: 0.124 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.125 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.136 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.125 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.131 초
# Detection 수행시간: 0.132 초
# Detection 수행시간: 0.125 초
# Detection 수행시간: 0.124 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.125 초
# Detection 수행시간: 0.134 초
# Detection 수행시간: 0.125 초
# Detection 수행시간: 0.13 초
# Detection 수행시간: 0.137 초
# Detection 수행시간: 0.131 초
# Detection 수행시간: 0.124 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.132 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.135 초
# Detection 수행시간: 0.139 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.124 초
# Detection 수행시간: 0.143 초
# Detection 수행시간: 0.133 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.135 초
# Detection 수행시간: 0.136 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.13 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.131 초
# Detection 수행시간: 0.122 초
# Detection 수행시간: 0.133 초
# Detection 수행시간: 0.134 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.123 초
# Detection 수행시간: 0.137 초
# Detection 수행시간: 0.125 초
# Detection 수행시간: 0.132 초
# Detection 수행시간: 0.112 초
# Detection 수행시간: 0.136 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.123 초
# Detection 수행시간: 0.134 초
# Detection 수행시간: 0.132 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.133 초
# Detection 수행시간: 0.137 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.136 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.132 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.116 초
# Detection 수행시간: 0.123 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.14 초
# Detection 수행시간: 0.133 초
# Detection 수행시간: 0.133 초
# Detection 수행시간: 0.115 초
# Detection 수행시간: 0.103 초
# Detection 수행시간: 0.096 초
# Detection 수행시간: 0.13 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.134 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.134 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.131 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.134 초
# Detection 수행시간: 0.138 초
# Detection 수행시간: 0.131 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.132 초
# Detection 수행시간: 0.142 초
# Detection 수행시간: 0.134 초
# Detection 수행시간: 0.134 초
# Detection 수행시간: 0.138 초
# Detection 수행시간: 0.109 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.113 초
# Detection 수행시간: 0.144 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.135 초
# Detection 수행시간: 0.142 초
# Detection 수행시간: 0.133 초
# Detection 수행시간: 0.133 초
# Detection 수행시간: 0.124 초
# Detection 수행시간: 0.14 초
# Detection 수행시간: 0.147 초
# Detection 수행시간: 0.13 초
# Detection 수행시간: 0.139 초
# Detection 수행시간: 0.132 초
# Detection 수행시간: 0.138 초
# Detection 수행시간: 0.135 초
# Detection 수행시간: 0.149 초
# Detection 수행시간: 0.13 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.136 초
# Detection 수행시간: 0.151 초
# Detection 수행시간: 0.133 초
# Detection 수행시간: 0.133 초
# Detection 수행시간: 0.144 초
# Detection 수행시간: 0.13 초
# Detection 수행시간: 0.134 초
# Detection 수행시간: 0.142 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.134 초
# Detection 수행시간: 0.136 초
# Detection 수행시간: 0.141 초
# Detection 수행시간: 0.134 초
# Detection 수행시간: 0.134 초
# Detection 수행시간: 0.137 초
# Detection 수행시간: 0.136 초
# Detection 수행시간: 0.143 초
# Detection 수행시간: 0.12 초
# Detection 수행시간: 0.135 초
# Detection 수행시간: 0.135 초
# Detection 수행시간: 0.136 초
# Detection 수행시간: 0.177 초
# Detection 수행시간: 0.157 초
# Detection 수행시간: 0.143 초
# Detection 수행시간: 0.142 초
# Detection 수행시간: 0.134 초
# Detection 수행시간: 0.14 초
# Detection 수행시간: 0.139 초
# Detection 수행시간: 0.133 초
# Detection 수행시간: 0.14 초
# Detection 수행시간: 0.138 초
# Detection 수행시간: 0.139 초
# Detection 수행시간: 0.131 초
# Detection 수행시간: 0.137 초
# Detection 수행시간: 0.134 초
# Detection 수행시간: 0.101 초
# Detection 수행시간: 0.133 초
# Detection 수행시간: 0.139 초
# Detection 수행시간: 0.133 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.133 초
# Detection 수행시간: 0.13 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.133 초
# Detection 수행시간: 0.106 초
# Detection 수행시간: 0.131 초
# Detection 수행시간: 0.131 초
# Detection 수행시간: 0.131 초
# Detection 수행시간: 0.132 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.124 초
# Detection 수행시간: 0.131 초
# Detection 수행시간: 0.13 초
# Detection 수행시간: 0.132 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.143 초
# Detection 수행시간: 0.13 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.132 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.134 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.13 초
# Detection 수행시간: 0.136 초
# Detection 수행시간: 0.122 초
# Detection 수행시간: 0.13 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.131 초
# Detection 수행시간: 0.188 초
# Detection 수행시간: 0.194 초
# Detection 수행시간: 0.218 초
# Detection 수행시간: 0.201 초
# Detection 수행시간: 0.208 초
# Detection 수행시간: 0.204 초
# Detection 수행시간: 0.209 초
# Detection 수행시간: 0.211 초
# Detection 수행시간: 0.15 초
# Detection 수행시간: 0.133 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.125 초
# Detection 수행시간: 0.131 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.13 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.146 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.133 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.132 초
# Detection 수행시간: 0.124 초
# Detection 수행시간: 0.118 초
# Detection 수행시간: 0.132 초
# Detection 수행시간: 0.111 초
# Detection 수행시간: 0.125 초
# Detection 수행시간: 0.137 초
# Detection 수행시간: 0.124 초
# Detection 수행시간: 0.131 초
# Detection 수행시간: 0.125 초
# Detection 수행시간: 0.133 초
# Detection 수행시간: 0.098 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.135 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.124 초
# Detection 수행시간: 0.13 초
# Detection 수행시간: 0.136 초
# Detection 수행시간: 0.124 초
# Detection 수행시간: 0.124 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.131 초
# Detection 수행시간: 0.136 초
# Detection 수행시간: 0.132 초
# Detection 수행시간: 0.12 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.13 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.122 초
# Detection 수행시간: 0.134 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.133 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.131 초
# Detection 수행시간: 0.135 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.134 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.131 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.124 초
# Detection 수행시간: 0.131 초
# Detection 수행시간: 0.123 초
# Detection 수행시간: 0.132 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.13 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.131 초
# Detection 수행시간: 0.13 초
# Detection 수행시간: 0.134 초
# Detection 수행시간: 0.131 초
# Detection 수행시간: 0.125 초
# Detection 수행시간: 0.09 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.13 초
# Detection 수행시간: 0.125 초
# Detection 수행시간: 0.13 초
# Detection 수행시간: 0.14 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.13 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.119 초
# Detection 수행시간: 0.124 초
# Detection 수행시간: 0.142 초
# Detection 수행시간: 0.141 초
# Detection 수행시간: 0.133 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.131 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.131 초
# Detection 수행시간: 0.134 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.13 초
# Detection 수행시간: 0.12 초
# Detection 수행시간: 0.123 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.134 초
# Detection 수행시간: 0.13 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.11 초
# Detection 수행시간: 0.132 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.125 초
# Detection 수행시간: 0.136 초
# Detection 수행시간: 0.132 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.131 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.131 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.131 초
# Detection 수행시간: 0.125 초
# Detection 수행시간: 0.135 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.115 초
# Detection 수행시간: 0.134 초
# Detection 수행시간: 0.122 초
# Detection 수행시간: 0.133 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.13 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.117 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.125 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.131 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.115 초
# Detection 수행시간: 0.096 초
# Detection 수행시간: 0.122 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.118 초
# Detection 수행시간: 0.096 초
# Detection 수행시간: 0.103 초
# Detection 수행시간: 0.137 초
# Detection 수행시간: 0.13 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.13 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.134 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.133 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.134 초
# Detection 수행시간: 0.134 초
# Detection 수행시간: 0.131 초
# Detection 수행시간: 0.144 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.134 초
# Detection 수행시간: 0.132 초
# Detection 수행시간: 0.143 초
# Detection 수행시간: 0.136 초
# Detection 수행시간: 0.125 초
# Detection 수행시간: 0.134 초
# Detection 수행시간: 0.125 초
# Detection 수행시간: 0.132 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.13 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.134 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.131 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.133 초
# Detection 수행시간: 0.148 초
# Detection 수행시간: 0.131 초
# Detection 수행시간: 0.125 초
# Detection 수행시간: 0.133 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.125 초
# Detection 수행시간: 0.123 초
# Detection 수행시간: 0.134 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.13 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.131 초
# Detection 수행시간: 0.125 초
# Detection 수행시간: 0.121 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.138 초
# Detection 수행시간: 0.124 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.13 초
# Detection 수행시간: 0.133 초
# Detection 수행시간: 0.125 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.125 초
# Detection 수행시간: 0.131 초
# Detection 수행시간: 0.123 초
# Detection 수행시간: 0.13 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.125 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.14 초
# Detection 수행시간: 0.124 초
# Detection 수행시간: 0.098 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.096 초
# Detection 수행시간: 0.125 초
# Detection 수행시간: 0.122 초
# Detection 수행시간: 0.115 초
# Detection 수행시간: 0.142 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.119 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.13 초
# Detection 수행시간: 0.125 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.13 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.123 초
# Detection 수행시간: 0.123 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.124 초
# Detection 수행시간: 0.13 초
# Detection 수행시간: 0.133 초
# Detection 수행시간: 0.131 초
# Detection 수행시간: 0.119 초
# Detection 수행시간: 0.137 초
# Detection 수행시간: 0.123 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.134 초
# Detection 수행시간: 0.153 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.125 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.125 초
# Detection 수행시간: 0.105 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.133 초
# Detection 수행시간: 0.101 초
# Detection 수행시간: 0.12 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.137 초
# Detection 수행시간: 0.132 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.134 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.134 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.132 초
# Detection 수행시간: 0.099 초
# Detection 수행시간: 0.108 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.13 초
# Detection 수행시간: 0.125 초
# Detection 수행시간: 0.14 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.125 초
# Detection 수행시간: 0.125 초
# Detection 수행시간: 0.139 초
# Detection 수행시간: 0.119 초
# Detection 수행시간: 0.134 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.107 초
# Detection 수행시간: 0.13 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.124 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.136 초
# Detection 수행시간: 0.13 초
# Detection 수행시간: 0.124 초
# Detection 수행시간: 0.13 초
# Detection 수행시간: 0.125 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.107 초
# Detection 수행시간: 0.101 초
# Detection 수행시간: 0.137 초
# Detection 수행시간: 0.131 초
# Detection 수행시간: 0.125 초
# Detection 수행시간: 0.124 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.143 초
# Detection 수행시간: 0.125 초
# Detection 수행시간: 0.131 초
# Detection 수행시간: 0.131 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.125 초
# Detection 수행시간: 0.131 초
# Detection 수행시간: 0.132 초
# Detection 수행시간: 0.132 초
# Detection 수행시간: 0.13 초
# Detection 수행시간: 0.13 초
# Detection 수행시간: 0.123 초
# Detection 수행시간: 0.13 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.132 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.13 초
# Detection 수행시간: 0.145 초
# Detection 수행시간: 0.135 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.132 초
# Detection 수행시간: 0.125 초
# Detection 수행시간: 0.13 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.124 초
# Detection 수행시간: 0.124 초
# Detection 수행시간: 0.121 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.124 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.125 초
# Detection 수행시간: 0.135 초
# Detection 수행시간: 0.133 초
# Detection 수행시간: 0.133 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.134 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.13 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.137 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.13 초
# Detection 수행시간: 0.124 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.14 초
# Detection 수행시간: 0.131 초
# Detection 수행시간: 0.123 초
# Detection 수행시간: 0.134 초
# Detection 수행시간: 0.14 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.136 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.136 초
# Detection 수행시간: 0.133 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.133 초
# Detection 수행시간: 0.13 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.13 초
# Detection 수행시간: 0.131 초
# Detection 수행시간: 0.114 초
# Detection 수행시간: 0.139 초
# Detection 수행시간: 0.15 초
# Detection 수행시간: 0.133 초
# Detection 수행시간: 0.133 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.138 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.137 초
# Detection 수행시간: 0.124 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.13 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.125 초
# Detection 수행시간: 0.139 초
# Detection 수행시간: 0.131 초
# Detection 수행시간: 0.13 초
# Detection 수행시간: 0.123 초
# Detection 수행시간: 0.137 초
# Detection 수행시간: 0.125 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.138 초
# Detection 수행시간: 0.133 초
# Detection 수행시간: 0.123 초
# Detection 수행시간: 0.125 초
# Detection 수행시간: 0.125 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.136 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.132 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.133 초
# Detection 수행시간: 0.124 초
# Detection 수행시간: 0.132 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.132 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.123 초
# Detection 수행시간: 0.136 초
# Detection 수행시간: 0.124 초
# Detection 수행시간: 0.13 초
# Detection 수행시간: 0.13 초
# Detection 수행시간: 0.125 초
# Detection 수행시간: 0.125 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.151 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.121 초
# Detection 수행시간: 0.119 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.135 초
# Detection 수행시간: 0.123 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.135 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.119 초
# Detection 수행시간: 0.134 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.13 초
# Detection 수행시간: 0.14 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.133 초
# Detection 수행시간: 0.134 초
# Detection 수행시간: 0.121 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.13 초
# Detection 수행시간: 0.124 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.111 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.123 초
# Detection 수행시간: 0.138 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.138 초
# Detection 수행시간: 0.133 초
# Detection 수행시간: 0.136 초
# Detection 수행시간: 0.124 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.094 초
# Detection 수행시간: 0.13 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.141 초
# Detection 수행시간: 0.133 초
# Detection 수행시간: 0.125 초
# Detection 수행시간: 0.131 초
# Detection 수행시간: 0.109 초
# Detection 수행시간: 0.13 초
# Detection 수행시간: 0.123 초
# Detection 수행시간: 0.12 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.106 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.124 초
# Detection 수행시간: 0.094 초
# Detection 수행시간: 0.125 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.13 초
# Detection 수행시간: 0.114 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.125 초
# Detection 수행시간: 0.136 초
# Detection 수행시간: 0.114 초
# Detection 수행시간: 0.131 초
# Detection 수행시간: 0.123 초
# Detection 수행시간: 0.14 초
# Detection 수행시간: 0.125 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.125 초
# Detection 수행시간: 0.134 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.102 초
# Detection 수행시간: 0.088 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.12 초
# Detection 수행시간: 0.13 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.124 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.125 초
# Detection 수행시간: 0.139 초
# Detection 수행시간: 0.123 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.131 초
# Detection 수행시간: 0.135 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.132 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.125 초
# Detection 수행시간: 0.135 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.123 초
# Detection 수행시간: 0.125 초
# Detection 수행시간: 0.09 초
# Detection 수행시간: 0.119 초
# Detection 수행시간: 0.123 초
# Detection 수행시간: 0.139 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.131 초
# Detection 수행시간: 0.125 초
# Detection 수행시간: 0.094 초
# Detection 수행시간: 0.13 초
# Detection 수행시간: 0.13 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.131 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.13 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.132 초
# Detection 수행시간: 0.13 초
# Detection 수행시간: 0.13 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.141 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.13 초
# Detection 수행시간: 0.132 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.134 초
# Detection 수행시간: 0.125 초
# Detection 수행시간: 0.13 초
# Detection 수행시간: 0.123 초
# Detection 수행시간: 0.131 초
# Detection 수행시간: 0.132 초
# Detection 수행시간: 0.131 초
# Detection 수행시간: 0.13 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.134 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.134 초
# Detection 수행시간: 0.123 초
# Detection 수행시간: 0.131 초
# Detection 수행시간: 0.131 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.125 초
# Detection 수행시간: 0.136 초
# Detection 수행시간: 0.095 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.131 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.13 초
# Detection 수행시간: 0.133 초
# Detection 수행시간: 0.123 초
# Detection 수행시간: 0.13 초
# Detection 수행시간: 0.125 초
# Detection 수행시간: 0.132 초
# Detection 수행시간: 0.125 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.133 초
# Detection 수행시간: 0.135 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.131 초
# Detection 수행시간: 0.13 초
# Detection 수행시간: 0.134 초
# Detection 수행시간: 0.124 초
# Detection 수행시간: 0.132 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.13 초
# Detection 수행시간: 0.125 초
# Detection 수행시간: 0.133 초
# Detection 수행시간: 0.125 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.13 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.131 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.112 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.137 초
# Detection 수행시간: 0.134 초
# Detection 수행시간: 0.124 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.123 초
# Detection 수행시간: 0.13 초
# Detection 수행시간: 0.123 초
# Detection 수행시간: 0.135 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.13 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.14 초
# Detection 수행시간: 0.131 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.161 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.125 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.125 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.13 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.131 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.123 초
# Detection 수행시간: 0.136 초
# Detection 수행시간: 0.125 초
# Detection 수행시간: 0.133 초
# Detection 수행시간: 0.102 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.131 초
# Detection 수행시간: 0.133 초
# Detection 수행시간: 0.13 초
# Detection 수행시간: 0.132 초
# Detection 수행시간: 0.131 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.13 초
# Detection 수행시간: 0.12 초
# Detection 수행시간: 0.11 초
# Detection 수행시간: 0.114 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.134 초
# Detection 수행시간: 0.13 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.133 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.124 초
# Detection 수행시간: 0.136 초
# Detection 수행시간: 0.113 초
# Detection 수행시간: 0.124 초
# Detection 수행시간: 0.124 초
# Detection 수행시간: 0.132 초
# Detection 수행시간: 0.125 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.132 초
# Detection 수행시간: 0.124 초
# Detection 수행시간: 0.135 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.122 초
# Detection 수행시간: 0.131 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.118 초
# Detection 수행시간: 0.141 초
# Detection 수행시간: 0.125 초
# Detection 수행시간: 0.125 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.114 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.123 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.13 초
# Detection 수행시간: 0.125 초
# Detection 수행시간: 0.133 초
# Detection 수행시간: 0.131 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.132 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.132 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.124 초
# Detection 수행시간: 0.132 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.133 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.113 초
# Detection 수행시간: 0.104 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.113 초
# Detection 수행시간: 0.134 초
# Detection 수행시간: 0.132 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.111 초
# Detection 수행시간: 0.135 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.124 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.133 초
# Detection 수행시간: 0.132 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.127 초
# Detection 수행시간: 0.129 초
# Detection 수행시간: 0.125 초
# Detection 수행시간: 0.132 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.131 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.133 초
# Detection 수행시간: 0.125 초
# Detection 수행시간: 0.126 초
# Detection 수행시간: 0.128 초
# Detection 수행시간: 0.134 초
# Detection 수행시간: 0.124 초
# Detection 수행시간: 0.134 초
# Detection 수행시간: 0.131 초
# 더 이상 처리할 frame이 없습니다.
